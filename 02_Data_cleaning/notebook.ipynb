# %%
import pandas as pd

# %%
df = pd.read_csv("/home/sanjay/Project/Project100/Pandas-learning-projects/Data-cleaning/data/employees_dirty.csv")

# %%
df.head()
# Out:
#    EmployeeID     Name Department   Age Salary  Experience        City
# 0         101   Alice          IT  25.0  50000         2.0     Chennai
# 1         102      Bob         HR  29.0    NaN         5.0  Coimbatore
# 2         103  Charlie         IT   NaN  65000         4.0   Bangalore
# 3         104    David    Finance  35.0  72000         8.0         NaN
# 4         105      Eva         HR  28.0  58000         3.0  Coimbatore

# %%
df.head(10)
# Out:
#    EmployeeID     Name Department   Age Salary  Experience        City
# 0         101   Alice          IT  25.0  50000         2.0     Chennai
# 1         102      Bob         HR  29.0    NaN         5.0  Coimbatore
# 2         103  Charlie         IT   NaN  65000         4.0   Bangalore
# 3         104    David    Finance  35.0  72000         8.0         NaN
# 4         105      Eva         HR  28.0  58000         3.0  Coimbatore
# 5         106    Frank         IT  31.0  61000         6.0     Chennai
# 6         106    Frank         IT  31.0  61000         6.0     Chennai
# 7         107    Grace    finance  27.0  59000         4.0   Bangalore
# 8         108    Henry         HR  26.0    abc         2.0     Madurai
# 9         109      Ivy        IT   30.0  67000         NaN     Chennai

# %%
df.tail()
# Out:
#     EmployeeID   Name Department   Age Salary  Experience        City
# 6          106  Frank         IT  31.0  61000         6.0     Chennai
# 7          107  Grace    finance  27.0  59000         4.0   Bangalore
# 8          108  Henry         HR  26.0    abc         2.0     Madurai
# 9          109    Ivy        IT   30.0  67000         NaN     Chennai
# 10         110   Jack         HR  29.0  60000         5.0  Coimbatore

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  11 non-null     int64
#  1   Name        11 non-null     str
#  2   Department  11 non-null     str
#  3   Age         10 non-null     float64
#  4   Salary      10 non-null     str
#  5   Experience  10 non-null     float64
#  6   City        10 non-null     str
# dtypes: float64(2), int64(1), str(4)
# memory usage: 748.0 bytes

# %%
df.isnull()
# Out:
#     EmployeeID   Name  Department    Age  Salary  Experience   City
# 0        False  False       False  False   False       False  False
# 1        False  False       False  False    True       False  False
# 2        False  False       False   True   False       False  False
# 3        False  False       False  False   False       False   True
# 4        False  False       False  False   False       False  False
# 5        False  False       False  False   False       False  False
# 6        False  False       False  False   False       False  False
# 7        False  False       False  False   False       False  False
# 8        False  False       False  False   False       False  False
# 9        False  False       False  False   False        True  False
# 10       False  False       False  False   False       False  False

# %%
df.isnull().sum()
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Age           1
# Salary        1
# Experience    1
# City          1
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Age           1
# Salary        1
# Experience    1
# City          1
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Salary"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["Salary"] = pd.to_numeric(df["Salary"], errors="coerce")

# %%
df.isnull().sum()
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Age           0
# Salary        2
# Experience    1
# City          1
# dtype: int64

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())

# %%
df["Experience"] = df["Experience"].fillna(df["Experience"].median())

# %%
df["City"] = df["City"].fillna(df["City"].mode()[0])

# %%
df["Name"] = df["Name"].str.strip()

df["Department"] = df["Department"].str.strip()

df["City"] = df["City"].str.strip()

# %%
df["Department"] = df["Department"].str.title()

# %%
df["Name"] = df["Name"].str.title()

# %%
df["Department"].unique()
# Out:
# <StringArray>
# ['It', 'Hr', 'Finance']
# Length: 3, dtype: str

# %%
df["Department"].value_counts()
# Out:
# Department
# It         4
# Hr         4
# Finance    2
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# EmployeeID      int64
# Name              str
# Department        str
# Age           float64
# Salary        float64
# Experience    float64
# City              str
# dtype: object

# %%
df.isnull().sum()
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Age           0
# Salary        0
# Experience    0
# City          0
# dtype: int64

# %%
df.to_csv("output/cleaned_employees.csv", index=False)

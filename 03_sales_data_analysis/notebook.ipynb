# %%
import pandas as pd

# %%
df = pd.read_csv("/home/sanjay/Project/Project100/Pandas-learning-projects/sales-data-analysis/data/sales.csv")

# %%
df.head()

df.tail()

df.info()

df.describe()

df.shape

df.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   12 non-null     int64
#  1   Customer  12 non-null     str
#  2   City      12 non-null     str
#  3   Category  12 non-null     str
#  4   Product   12 non-null     str
#  5   Quantity  12 non-null     int64
#  6   Price     12 non-null     int64
#  7   Date      12 non-null     str
# dtypes: int64(3), str(5)
# memory usage: 900.0 bytes
# Index(['OrderID', 'Customer', 'City', 'Category', 'Product', 'Quantity',
#        'Price', 'Date'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# OrderID     0
# Customer    0
# City        0
# Category    0
# Product     0
# Quantity    0
# Price       0
# Date        0
# Revenue     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Revenue"] = df["Quantity"] * df["Price"]

# %%
df.head()
# Out:
#    OrderID Customer        City     Category   Product  Quantity  Price  \
# 0     1001    Alice     Chennai  Electronics    Laptop         1  55000
# 1     1002      Bob  Coimbatore    Furniture     Chair         4   2500
# 2     1003  Charlie   Bangalore  Electronics     Mouse         3    700
# 3     1004    David     Chennai    Furniture     Table         2   8000
# 4     1005      Eva     Madurai  Electronics  Keyboard         5   1200
#
#          Date  Revenue
# 0  2026-01-10    55000
# 1  2026-01-12    10000
# 2  2026-01-15     2100
# 3  2026-01-18    16000
# 4  2026-01-19     6000

# %%
df.to_csv("output/sales_with_revenue.csv", index=False)

# %%
df[df["Category"] == "Electronics"]
# Out:
#     OrderID Customer        City     Category     Product  Quantity  Price  \
# 0      1001    Alice     Chennai  Electronics      Laptop         1  55000
# 2      1003  Charlie   Bangalore  Electronics       Mouse         3    700
# 4      1005      Eva     Madurai  Electronics    Keyboard         5   1200
# 5      1006    Frank  Coimbatore  Electronics     Monitor         2  15000
# 7      1008    Henry     Chennai  Electronics  Headphones         6   2500
# 9      1010     Jack  Coimbatore  Electronics      Laptop         2  55000
# 11     1012     Liam   Bangalore  Electronics     Monitor         1  15000
#
#           Date  Revenue
# 0   2026-01-10    55000
# 2   2026-01-15     2100
# 4   2026-01-19     6000
# 5   2026-01-20    30000
# 7   2026-01-24    15000
# 9   2026-01-28   110000
# 11  2026-02-05    15000

# %%
df["Category"] == "Electronics"
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11     True
# Name: Category, dtype: bool

# %%
df[df["Price"] > 10000]
# Out:
#     OrderID Customer        City     Category   Product  Quantity  Price  \
# 0      1001    Alice     Chennai  Electronics    Laptop         1  55000
# 5      1006    Frank  Coimbatore  Electronics   Monitor         2  15000
# 6      1007    Grace   Bangalore    Furniture      Sofa         1  35000
# 8      1009      Ivy     Madurai    Furniture  Cupboard         1  18000
# 9      1010     Jack  Coimbatore  Electronics    Laptop         2  55000
# 11     1012     Liam   Bangalore  Electronics   Monitor         1  15000
#
#           Date  Revenue
# 0   2026-01-10    55000
# 5   2026-01-20    30000
# 6   2026-01-22    35000
# 8   2026-01-25    18000
# 9   2026-01-28   110000
# 11  2026-02-05    15000

# %%
df[(df["Category"] == "Electronics") & (df["Price"] > 10000)]
# Out:
#     OrderID Customer        City     Category  Product  Quantity  Price  \
# 0      1001    Alice     Chennai  Electronics   Laptop         1  55000
# 5      1006    Frank  Coimbatore  Electronics  Monitor         2  15000
# 9      1010     Jack  Coimbatore  Electronics   Laptop         2  55000
# 11     1012     Liam   Bangalore  Electronics  Monitor         1  15000
#
#           Date  Revenue
# 0   2026-01-10    55000
# 5   2026-01-20    30000
# 9   2026-01-28   110000
# 11  2026-02-05    15000

# %%
df[(df["City"] == "Chennai") | (df["City"] == "Bangalore")]
# Out:
#     OrderID Customer       City     Category     Product  Quantity  Price  \
# 0      1001    Alice    Chennai  Electronics      Laptop         1  55000
# 2      1003  Charlie  Bangalore  Electronics       Mouse         3    700
# 3      1004    David    Chennai    Furniture       Table         2   8000
# 6      1007    Grace  Bangalore    Furniture        Sofa         1  35000
# 7      1008    Henry    Chennai  Electronics  Headphones         6   2500
# 10     1011     Kate    Chennai    Furniture       Chair         8   2500
# 11     1012     Liam  Bangalore  Electronics     Monitor         1  15000
#
#           Date  Revenue
# 0   2026-01-10    55000
# 2   2026-01-15     2100
# 3   2026-01-18    16000
# 6   2026-01-22    35000
# 7   2026-01-24    15000
# 10  2026-02-02    20000
# 11  2026-02-05    15000

# %%
df[
(df["City"]=="Chennai") |
(df["City"]=="Madurai") |
(df["City"]=="Bangalore")
]
# Out:
#     OrderID Customer       City     Category     Product  Quantity  Price  \
# 0      1001    Alice    Chennai  Electronics      Laptop         1  55000
# 2      1003  Charlie  Bangalore  Electronics       Mouse         3    700
# 3      1004    David    Chennai    Furniture       Table         2   8000
# 4      1005      Eva    Madurai  Electronics    Keyboard         5   1200
# 6      1007    Grace  Bangalore    Furniture        Sofa         1  35000
# 7      1008    Henry    Chennai  Electronics  Headphones         6   2500
# 8      1009      Ivy    Madurai    Furniture    Cupboard         1  18000
# 10     1011     Kate    Chennai    Furniture       Chair         8   2500
# 11     1012     Liam  Bangalore  Electronics     Monitor         1  15000
#
#           Date  Revenue
# 0   2026-01-10    55000
# 2   2026-01-15     2100
# 3   2026-01-18    16000
# 4   2026-01-19     6000
# 6   2026-01-22    35000
# 7   2026-01-24    15000
# 8   2026-01-25    18000
# 10  2026-02-02    20000
# ...

# %%
df[df["City"].isin(["Chennai","Madurai","Bangalore"])]
# Out:
#     OrderID Customer       City     Category     Product  Quantity  Price  \
# 0      1001    Alice    Chennai  Electronics      Laptop         1  55000
# 2      1003  Charlie  Bangalore  Electronics       Mouse         3    700
# 3      1004    David    Chennai    Furniture       Table         2   8000
# 4      1005      Eva    Madurai  Electronics    Keyboard         5   1200
# 6      1007    Grace  Bangalore    Furniture        Sofa         1  35000
# 7      1008    Henry    Chennai  Electronics  Headphones         6   2500
# 8      1009      Ivy    Madurai    Furniture    Cupboard         1  18000
# 10     1011     Kate    Chennai    Furniture       Chair         8   2500
# 11     1012     Liam  Bangalore  Electronics     Monitor         1  15000
#
#           Date  Revenue
# 0   2026-01-10    55000
# 2   2026-01-15     2100
# 3   2026-01-18    16000
# 4   2026-01-19     6000
# 6   2026-01-22    35000
# 7   2026-01-24    15000
# 8   2026-01-25    18000
# 10  2026-02-02    20000
# ...

# %%
df[(df["Price"]>=2000) & (df["Price"]<=20000)]
# Out:
#     OrderID Customer        City     Category     Product  Quantity  Price  \
# 1      1002      Bob  Coimbatore    Furniture       Chair         4   2500
# 3      1004    David     Chennai    Furniture       Table         2   8000
# 5      1006    Frank  Coimbatore  Electronics     Monitor         2  15000
# 7      1008    Henry     Chennai  Electronics  Headphones         6   2500
# 8      1009      Ivy     Madurai    Furniture    Cupboard         1  18000
# 10     1011     Kate     Chennai    Furniture       Chair         8   2500
# 11     1012     Liam   Bangalore  Electronics     Monitor         1  15000
#
#           Date  Revenue
# 1   2026-01-12    10000
# 3   2026-01-18    16000
# 5   2026-01-20    30000
# 7   2026-01-24    15000
# 8   2026-01-25    18000
# 10  2026-02-02    20000
# 11  2026-02-05    15000

# %%
df[df["Price"].between(2000,20000)]
# Out:
#     OrderID Customer        City     Category     Product  Quantity  Price  \
# 1      1002      Bob  Coimbatore    Furniture       Chair         4   2500
# 3      1004    David     Chennai    Furniture       Table         2   8000
# 5      1006    Frank  Coimbatore  Electronics     Monitor         2  15000
# 7      1008    Henry     Chennai  Electronics  Headphones         6   2500
# 8      1009      Ivy     Madurai    Furniture    Cupboard         1  18000
# 10     1011     Kate     Chennai    Furniture       Chair         8   2500
# 11     1012     Liam   Bangalore  Electronics     Monitor         1  15000
#
#           Date  Revenue
# 1   2026-01-12    10000
# 3   2026-01-18    16000
# 5   2026-01-20    30000
# 7   2026-01-24    15000
# 8   2026-01-25    18000
# 10  2026-02-02    20000
# 11  2026-02-05    15000

# %%
df.sort_values("Price", ascending=False)
# Out:
#     OrderID Customer        City     Category     Product  Quantity  Price  \
# 0      1001    Alice     Chennai  Electronics      Laptop         1  55000
# 9      1010     Jack  Coimbatore  Electronics      Laptop         2  55000
# 6      1007    Grace   Bangalore    Furniture        Sofa         1  35000
# 8      1009      Ivy     Madurai    Furniture    Cupboard         1  18000
# 11     1012     Liam   Bangalore  Electronics     Monitor         1  15000
# 5      1006    Frank  Coimbatore  Electronics     Monitor         2  15000
# 3      1004    David     Chennai    Furniture       Table         2   8000
# 1      1002      Bob  Coimbatore    Furniture       Chair         4   2500
# 10     1011     Kate     Chennai    Furniture       Chair         8   2500
# 7      1008    Henry     Chennai  Electronics  Headphones         6   2500
# 4      1005      Eva     Madurai  Electronics    Keyboard         5   1200
# ...

# %%
df.sort_values("Price")
# Out:
#     OrderID Customer        City     Category     Product  Quantity  Price  \
# 2      1003  Charlie   Bangalore  Electronics       Mouse         3    700
# 4      1005      Eva     Madurai  Electronics    Keyboard         5   1200
# 7      1008    Henry     Chennai  Electronics  Headphones         6   2500
# 1      1002      Bob  Coimbatore    Furniture       Chair         4   2500
# 10     1011     Kate     Chennai    Furniture       Chair         8   2500
# 3      1004    David     Chennai    Furniture       Table         2   8000
# 11     1012     Liam   Bangalore  Electronics     Monitor         1  15000
# 5      1006    Frank  Coimbatore  Electronics     Monitor         2  15000
# 8      1009      Ivy     Madurai    Furniture    Cupboard         1  18000
# 6      1007    Grace   Bangalore    Furniture        Sofa         1  35000
# 0      1001    Alice     Chennai  Electronics      Laptop         1  55000
# ...

# %%
df.sort_values("Revenue", ascending=False)
# Out:
#     OrderID Customer        City     Category     Product  Quantity  Price  \
# 9      1010     Jack  Coimbatore  Electronics      Laptop         2  55000
# 0      1001    Alice     Chennai  Electronics      Laptop         1  55000
# 6      1007    Grace   Bangalore    Furniture        Sofa         1  35000
# 5      1006    Frank  Coimbatore  Electronics     Monitor         2  15000
# 10     1011     Kate     Chennai    Furniture       Chair         8   2500
# 8      1009      Ivy     Madurai    Furniture    Cupboard         1  18000
# 3      1004    David     Chennai    Furniture       Table         2   8000
# 7      1008    Henry     Chennai  Electronics  Headphones         6   2500
# 11     1012     Liam   Bangalore  Electronics     Monitor         1  15000
# 1      1002      Bob  Coimbatore    Furniture       Chair         4   2500
# 4      1005      Eva     Madurai  Electronics    Keyboard         5   1200
# ...

# %%
df.sort_values("Price", ascending=False).head(5)
# Out:
#     OrderID Customer        City     Category   Product  Quantity  Price  \
# 0      1001    Alice     Chennai  Electronics    Laptop         1  55000
# 9      1010     Jack  Coimbatore  Electronics    Laptop         2  55000
# 6      1007    Grace   Bangalore    Furniture      Sofa         1  35000
# 8      1009      Ivy     Madurai    Furniture  Cupboard         1  18000
# 11     1012     Liam   Bangalore  Electronics   Monitor         1  15000
#
#           Date  Revenue
# 0   2026-01-10    55000
# 9   2026-01-28   110000
# 6   2026-01-22    35000
# 8   2026-01-25    18000
# 11  2026-02-05    15000

# %%
df.nlargest(5, "Price")
# Out:
#    OrderID Customer        City     Category   Product  Quantity  Price  \
# 0     1001    Alice     Chennai  Electronics    Laptop         1  55000
# 9     1010     Jack  Coimbatore  Electronics    Laptop         2  55000
# 6     1007    Grace   Bangalore    Furniture      Sofa         1  35000
# 8     1009      Ivy     Madurai    Furniture  Cupboard         1  18000
# 5     1006    Frank  Coimbatore  Electronics   Monitor         2  15000
#
#          Date  Revenue
# 0  2026-01-10    55000
# 9  2026-01-28   110000
# 6  2026-01-22    35000
# 8  2026-01-25    18000
# 5  2026-01-20    30000

# %%
df.nsmallest(3, "Price")
# Out:
#    OrderID Customer        City     Category   Product  Quantity  Price  \
# 2     1003  Charlie   Bangalore  Electronics     Mouse         3    700
# 4     1005      Eva     Madurai  Electronics  Keyboard         5   1200
# 1     1002      Bob  Coimbatore    Furniture     Chair         4   2500
#
#          Date  Revenue
# 2  2026-01-15     2100
# 4  2026-01-19     6000
# 1  2026-01-12    10000

# %%
df.groupby("City")["Revenue"].sum()
# Out:
# City
# Bangalore      52100
# Chennai       106000
# Coimbatore    150000
# Madurai        24000
# Name: Revenue, dtype: int64

# %%
df.groupby("Category")["Revenue"].sum()
# Out:
# Category
# Electronics    233100
# Furniture       99000
# Name: Revenue, dtype: int64

# %%
df.groupby("Category")["Price"].mean()
# Out:
# Category
# Electronics    20628.571429
# Furniture      13200.000000
# Name: Price, dtype: float64

# %%
df.groupby("Category")["Quantity"].sum()
# Out:
# Category
# Electronics    20
# Furniture      16
# Name: Quantity, dtype: int64

# %%
df.groupby("Customer")["Revenue"].sum()
# Out:
# Customer
# Alice       55000
# Bob         10000
# Charlie      2100
# David       16000
# Eva          6000
# Frank       30000
# Grace       35000
# Henry       15000
# Ivy         18000
# Jack       110000
# Kate        20000
# Liam        15000
# Name: Revenue, dtype: int64

# %%
df.groupby("Customer")["Revenue"].sum().sort_values(ascending=False)
# Out:
# Customer
# Jack       110000
# Alice       55000
# Grace       35000
# Frank       30000
# Kate        20000
# Ivy         18000
# David       16000
# Henry       15000
# Liam        15000
# Bob         10000
# Eva          6000
# Charlie      2100
# Name: Revenue, dtype: int64

# %%
df.groupby("Customer")["Revenue"].sum().idxmax()
# Out:
# 'Jack'

# %%
df.groupby("City")["Revenue"].sum().idxmax()
# Out:
# 'Coimbatore'

# %%
df.groupby("Category")["Price"].agg(["mean","max","min"])
# Out:
#                      mean    max   min
# Category
# Electronics  20628.571429  55000   700
# Furniture    13200.000000  35000  2500

# %%
df.groupby("City")["Revenue"].agg(
    ["sum","mean","max","min"]
)
# Out:
#                sum          mean     max    min
# City
# Bangalore    52100  17366.666667   35000   2100
# Chennai     106000  26500.000000   55000  15000
# Coimbatore  150000  50000.000000  110000  10000
# Madurai      24000  12000.000000   18000   6000

# %%
city_sales = df.groupby("City")["Revenue"].sum().reset_index()

# %%
city_sales.to_csv(
    "output/city_sales_report.csv",
    index=False
)
